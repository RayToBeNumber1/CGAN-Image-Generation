# %%
import tensorflow as tf
from matplotlib import pyplot as plt
from numpy import asarray
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_PATH = '/content/drive/MyDrive/CGAN_PIX2PIX/train_dataset2'
test_PATH = '/content/drive/MyDrive/CGAN_PIX2PIX/test_dataset2'

# %%
# this function convert the images to a tensor array, and matches a input images and a real image to a image pair.
def file_2_tfArray(numOfImage, path):
    suffix = path.split('/')[-1]
    for i in range(1, numOfImage+1):
        print(f'{suffix}: image {i} loaded')
        input_image = tf.io.read_file(path + f'/input/{i}.png')
        input_image = tf.io.decode_jpeg(input_image, channels= 3)
        input_image = tf.cast(input_image, tf.float32)

        
        real_image = tf.io.read_file(path + f'/target/{i}.png')
        real_image = tf.io.decode_jpeg(real_image, channels= 3)
        real_image = tf.cast(real_image, tf.float32)

        image = tf.concat([input_image, real_image], axis=1)

        if i == 1:
            image_tensor_array = tf.constant(np.asarray([image]))
        else:
            image_tensor_array = tf.concat([image_tensor_array, np.asarray([image])],axis=0)

    return image_tensor_array

# %%
train_image_tensor_array = file_2_tfArray(500, train_PATH)
test_image_tensor_array = file_2_tfArray(100, test_PATH)
# Out:
# train_dataset2: image 1 loaded
# train_dataset2: image 2 loaded
# train_dataset2: image 3 loaded
# train_dataset2: image 4 loaded
# train_dataset2: image 5 loaded
# train_dataset2: image 6 loaded
# train_dataset2: image 7 loaded
# train_dataset2: image 8 loaded
# train_dataset2: image 9 loaded
# train_dataset2: image 10 loaded
# train_dataset2: image 11 loaded
# train_dataset2: image 12 loaded
# train_dataset2: image 13 loaded
# train_dataset2: image 14 loaded
# train_dataset2: image 15 loaded
# train_dataset2: image 16 loaded
# train_dataset2: image 17 loaded
# train_dataset2: image 18 loaded
# train_dataset2: image 19 loaded
# train_dataset2: image 20 loaded
# train_dataset2: image 21 loaded
# train_dataset2: image 22 loaded
# train_dataset2: image 23 loaded
# train_dataset2: image 24 loaded
# train_dataset2: image 25 loaded
# train_dataset2: image 26 loaded
# train_dataset2: image 27 loaded
# train_dataset2: image 28 loaded
# train_dataset2: image 29 loaded
# train_dataset2: image 30 loaded
# train_dataset2: image 31 loaded
# train_dataset2: image 32 loaded
# train_dataset2: image 33 loaded
# train_dataset2: image 34 loaded
# train_dataset2: image 35 loaded
# train_dataset2: image 36 loaded
# train_dataset2: image 37 loaded
# train_dataset2: image 38 loaded
# train_dataset2: image 39 loaded
# train_dataset2: image 40 loaded
# train_dataset2: image 41 loaded
# train_dataset2: image 42 loaded
# train_dataset2: image 43 loaded
# train_dataset2: image 44 loaded
# train_dataset2: image 45 loaded
# train_dataset2: image 46 loaded
# train_dataset2: image 47 loaded
# train_dataset2: image 48 loaded
# train_dataset2: image 49 loaded
# train_dataset2: image 50 loaded
# train_dataset2: image 51 loaded
# train_dataset2: image 52 loaded
# train_dataset2: image 53 loaded
# train_dataset2: image 54 loaded
# train_dataset2: image 55 loaded
# train_dataset2: image 56 loaded
# train_dataset2: image 57 loaded
# train_dataset2: image 58 loaded
# train_dataset2: image 59 loaded
# train_dataset2: image 60 loaded
# train_dataset2: image 61 loaded
# train_dataset2: image 62 loaded
# train_dataset2: image 63 loaded
# train_dataset2: image 64 loaded
# train_dataset2: image 65 loaded
# train_dataset2: image 66 loaded
# train_dataset2: image 67 loaded
# train_dataset2: image 68 loaded
# train_dataset2: image 69 loaded
# train_dataset2: image 70 loaded
# train_dataset2: image 71 loaded
# train_dataset2: image 72 loaded
# train_dataset2: image 73 loaded
# train_dataset2: image 74 loaded
# train_dataset2: image 75 loaded
# train_dataset2: image 76 loaded
# train_dataset2: image 77 loaded
# train_dataset2: image 78 loaded
# train_dataset2: image 79 loaded
# train_dataset2: image 80 loaded
# train_dataset2: image 81 loaded
# train_dataset2: image 82 loaded
# train_dataset2: image 83 loaded
# train_dataset2: image 84 loaded
# train_dataset2: image 85 loaded
# train_dataset2: image 86 loaded
# train_dataset2: image 87 loaded
# train_dataset2: image 88 loaded
# train_dataset2: image 89 loaded
# train_dataset2: image 90 loaded
# train_dataset2: image 91 loaded
# train_dataset2: image 92 loaded
# train_dataset2: image 93 loaded
# train_dataset2: image 94 loaded
# train_dataset2: image 95 loaded
# train_dataset2: image 96 loaded
# train_dataset2: image 97 loaded
# train_dataset2: image 98 loaded
# train_dataset2: image 99 loaded
# train_dataset2: image 100 loaded
# train_dataset2: image 101 loaded
# train_dataset2: image 102 loaded
# train_dataset2: image 103 loaded
# train_dataset2: image 104 loaded
# train_dataset2: image 105 loaded
# train_dataset2: image 106 loaded
# train_dataset2: image 107 loaded
# train_dataset2: image 108 loaded
# train_dataset2: image 109 loaded
# train_dataset2: image 110 loaded
# train_dataset2: image 111 loaded
# train_dataset2: image 112 loaded
# train_dataset2: image 113 loaded
# train_dataset2: image 114 loaded
# train_dataset2: image 115 loaded
# train_dataset2: image 116 loaded
# train_dataset2: image 117 loaded
# train_dataset2: image 118 loaded
# train_dataset2: image 119 loaded
# train_dataset2: image 120 loaded
# train_dataset2: image 121 loaded
# train_dataset2: image 122 loaded
# train_dataset2: image 123 loaded
# train_dataset2: image 124 loaded
# train_dataset2: image 125 loaded
# train_dataset2: image 126 loaded
# train_dataset2: image 127 loaded
# train_dataset2: image 128 loaded
# train_dataset2: image 129 loaded
# train_dataset2: image 130 loaded
# train_dataset2: image 131 loaded
# train_dataset2: image 132 loaded
# train_dataset2: image 133 loaded
# train_dataset2: image 134 loaded
# train_dataset2: image 135 loaded
# train_dataset2: image 136 loaded
# train_dataset2: image 137 loaded
# train_dataset2: image 138 loaded
# train_dataset2: image 139 loaded
# train_dataset2: image 140 loaded
# train_dataset2: image 141 loaded
# train_dataset2: image 142 loaded
# train_dataset2: image 143 loaded
# train_dataset2: image 144 loaded
# train_dataset2: image 145 loaded
# train_dataset2: image 146 loaded
# train_dataset2: image 147 loaded
# train_dataset2: image 148 loaded
# train_dataset2: image 149 loaded
# train_dataset2: image 150 loaded
# train_dataset2: image 151 loaded
# train_dataset2: image 152 loaded
# train_dataset2: image 153 loaded
# train_dataset2: image 154 loaded
# train_dataset2: image 155 loaded
# train_dataset2: image 156 loaded
# train_dataset2: image 157 loaded
# train_dataset2: image 158 loaded
# train_dataset2: image 159 loaded
# train_dataset2: image 160 loaded
# train_dataset2: image 161 loaded
# train_dataset2: image 162 loaded
# train_dataset2: image 163 loaded
# train_dataset2: image 164 loaded
# train_dataset2: image 165 loaded
# train_dataset2: image 166 loaded
# train_dataset2: image 167 loaded
# train_dataset2: image 168 loaded
# train_dataset2: image 169 loaded
# train_dataset2: image 170 loaded
# train_dataset2: image 171 loaded
# train_dataset2: image 172 loaded
# train_dataset2: image 173 loaded
# train_dataset2: image 174 loaded
# train_dataset2: image 175 loaded
# train_dataset2: image 176 loaded
# train_dataset2: image 177 loaded
# train_dataset2: image 178 loaded
# train_dataset2: image 179 loaded
# train_dataset2: image 180 loaded
# train_dataset2: image 181 loaded
# train_dataset2: image 182 loaded
# train_dataset2: image 183 loaded
# train_dataset2: image 184 loaded
# train_dataset2: image 185 loaded
# train_dataset2: image 186 loaded
# train_dataset2: image 187 loaded
# train_dataset2: image 188 loaded
# train_dataset2: image 189 loaded
# train_dataset2: image 190 loaded
# train_dataset2: image 191 loaded
# train_dataset2: image 192 loaded
# train_dataset2: image 193 loaded
# train_dataset2: image 194 loaded
# train_dataset2: image 195 loaded
# train_dataset2: image 196 loaded
# train_dataset2: image 197 loaded
# train_dataset2: image 198 loaded
# train_dataset2: image 199 loaded
# train_dataset2: image 200 loaded
# train_dataset2: image 201 loaded
# train_dataset2: image 202 loaded
# train_dataset2: image 203 loaded
# train_dataset2: image 204 loaded
# train_dataset2: image 205 loaded
# train_dataset2: image 206 loaded
# train_dataset2: image 207 loaded
# train_dataset2: image 208 loaded
# train_dataset2: image 209 loaded
# train_dataset2: image 210 loaded
# train_dataset2: image 211 loaded
# train_dataset2: image 212 loaded
# train_dataset2: image 213 loaded
# train_dataset2: image 214 loaded
# train_dataset2: image 215 loaded
# train_dataset2: image 216 loaded
# train_dataset2: image 217 loaded
# train_dataset2: image 218 loaded
# train_dataset2: image 219 loaded
# train_dataset2: image 220 loaded
# train_dataset2: image 221 loaded
# train_dataset2: image 222 loaded
# train_dataset2: image 223 loaded
# train_dataset2: image 224 loaded
# train_dataset2: image 225 loaded
# train_dataset2: image 226 loaded
# train_dataset2: image 227 loaded
# train_dataset2: image 228 loaded
# train_dataset2: image 229 loaded
# train_dataset2: image 230 loaded
# train_dataset2: image 231 loaded
# train_dataset2: image 232 loaded
# train_dataset2: image 233 loaded
# train_dataset2: image 234 loaded
# train_dataset2: image 235 loaded
# train_dataset2: image 236 loaded
# train_dataset2: image 237 loaded
# train_dataset2: image 238 loaded
# train_dataset2: image 239 loaded
# train_dataset2: image 240 loaded
# train_dataset2: image 241 loaded
# train_dataset2: image 242 loaded
# train_dataset2: image 243 loaded
# train_dataset2: image 244 loaded
# train_dataset2: image 245 loaded
# train_dataset2: image 246 loaded
# train_dataset2: image 247 loaded
# train_dataset2: image 248 loaded
# train_dataset2: image 249 loaded
# train_dataset2: image 250 loaded
# train_dataset2: image 251 loaded
# train_dataset2: image 252 loaded
# train_dataset2: image 253 loaded
# train_dataset2: image 254 loaded
# train_dataset2: image 255 loaded
# train_dataset2: image 256 loaded
# train_dataset2: image 257 loaded
# train_dataset2: image 258 loaded
# train_dataset2: image 259 loaded
# train_dataset2: image 260 loaded
# train_dataset2: image 261 loaded
# train_dataset2: image 262 loaded
# train_dataset2: image 263 loaded
# train_dataset2: image 264 loaded
# train_dataset2: image 265 loaded
# train_dataset2: image 266 loaded
# train_dataset2: image 267 loaded
# train_dataset2: image 268 loaded
# train_dataset2: image 269 loaded
# train_dataset2: image 270 loaded
# train_dataset2: image 271 loaded
# train_dataset2: image 272 loaded
# train_dataset2: image 273 loaded
# train_dataset2: image 274 loaded
# train_dataset2: image 275 loaded
# train_dataset2: image 276 loaded
# train_dataset2: image 277 loaded
# train_dataset2: image 278 loaded
# train_dataset2: image 279 loaded
# train_dataset2: image 280 loaded
# train_dataset2: image 281 loaded
# train_dataset2: image 282 loaded
# train_dataset2: image 283 loaded
# train_dataset2: image 284 loaded
# train_dataset2: image 285 loaded
# train_dataset2: image 286 loaded
# train_dataset2: image 287 loaded
# train_dataset2: image 288 loaded
# train_dataset2: image 289 loaded
# train_dataset2: image 290 loaded
# train_dataset2: image 291 loaded
# train_dataset2: image 292 loaded
# train_dataset2: image 293 loaded
# train_dataset2: image 294 loaded
# train_dataset2: image 295 loaded
# train_dataset2: image 296 loaded
# train_dataset2: image 297 loaded
# train_dataset2: image 298 loaded
# train_dataset2: image 299 loaded
# train_dataset2: image 300 loaded
# train_dataset2: image 301 loaded
# train_dataset2: image 302 loaded
# train_dataset2: image 303 loaded
# train_dataset2: image 304 loaded
# train_dataset2: image 305 loaded
# train_dataset2: image 306 loaded
# train_dataset2: image 307 loaded
# train_dataset2: image 308 loaded
# train_dataset2: image 309 loaded
# train_dataset2: image 310 loaded
# train_dataset2: image 311 loaded
# train_dataset2: image 312 loaded
# train_dataset2: image 313 loaded
# train_dataset2: image 314 loaded
# train_dataset2: image 315 loaded
# train_dataset2: image 316 loaded
# train_dataset2: image 317 loaded
# train_dataset2: image 318 loaded
# train_dataset2: image 319 loaded
# train_dataset2: image 320 loaded
# train_dataset2: image 321 loaded
# train_dataset2: image 322 loaded
# train_dataset2: image 323 loaded
# train_dataset2: image 324 loaded
# train_dataset2: image 325 loaded
# train_dataset2: image 326 loaded
# train_dataset2: image 327 loaded
# train_dataset2: image 328 loaded
# train_dataset2: image 329 loaded
# train_dataset2: image 330 loaded
# train_dataset2: image 331 loaded
# train_dataset2: image 332 loaded
# train_dataset2: image 333 loaded
# train_dataset2: image 334 loaded
# train_dataset2: image 335 loaded
# train_dataset2: image 336 loaded
# train_dataset2: image 337 loaded
# train_dataset2: image 338 loaded
# train_dataset2: image 339 loaded
# train_dataset2: image 340 loaded
# train_dataset2: image 341 loaded
# train_dataset2: image 342 loaded
# train_dataset2: image 343 loaded
# train_dataset2: image 344 loaded
# train_dataset2: image 345 loaded
# train_dataset2: image 346 loaded
# train_dataset2: image 347 loaded
# train_dataset2: image 348 loaded
# train_dataset2: image 349 loaded
# train_dataset2: image 350 loaded
# train_dataset2: image 351 loaded
# train_dataset2: image 352 loaded
# train_dataset2: image 353 loaded
# train_dataset2: image 354 loaded
# train_dataset2: image 355 loaded
# train_dataset2: image 356 loaded
# train_dataset2: image 357 loaded
# train_dataset2: image 358 loaded
# train_dataset2: image 359 loaded
# train_dataset2: image 360 loaded
# train_dataset2: image 361 loaded
# train_dataset2: image 362 loaded
# train_dataset2: image 363 loaded
# train_dataset2: image 364 loaded
# train_dataset2: image 365 loaded
# train_dataset2: image 366 loaded
# train_dataset2: image 367 loaded
# train_dataset2: image 368 loaded
# train_dataset2: image 369 loaded
# train_dataset2: image 370 loaded
# train_dataset2: image 371 loaded
# train_dataset2: image 372 loaded
# train_dataset2: image 373 loaded
# train_dataset2: image 374 loaded
# train_dataset2: image 375 loaded
# train_dataset2: image 376 loaded
# train_dataset2: image 377 loaded
# train_dataset2: image 378 loaded
# train_dataset2: image 379 loaded
# train_dataset2: image 380 loaded
# train_dataset2: image 381 loaded
# train_dataset2: image 382 loaded
# train_dataset2: image 383 loaded
# train_dataset2: image 384 loaded
# train_dataset2: image 385 loaded
# train_dataset2: image 386 loaded
# train_dataset2: image 387 loaded
# train_dataset2: image 388 loaded
# train_dataset2: image 389 loaded
# train_dataset2: image 390 loaded
# train_dataset2: image 391 loaded
# train_dataset2: image 392 loaded
# train_dataset2: image 393 loaded
# train_dataset2: image 394 loaded
# train_dataset2: image 395 loaded
# train_dataset2: image 396 loaded
# train_dataset2: image 397 loaded
# train_dataset2: image 398 loaded
# train_dataset2: image 399 loaded
# train_dataset2: image 400 loaded
# train_dataset2: image 401 loaded
# train_dataset2: image 402 loaded
# train_dataset2: image 403 loaded
# train_dataset2: image 404 loaded
# train_dataset2: image 405 loaded
# train_dataset2: image 406 loaded
# train_dataset2: image 407 loaded
# train_dataset2: image 408 loaded
# train_dataset2: image 409 loaded
# train_dataset2: image 410 loaded
# train_dataset2: image 411 loaded
# train_dataset2: image 412 loaded
# train_dataset2: image 413 loaded
# train_dataset2: image 414 loaded
# train_dataset2: image 415 loaded
# train_dataset2: image 416 loaded
# train_dataset2: image 417 loaded
# train_dataset2: image 418 loaded
# train_dataset2: image 419 loaded
# train_dataset2: image 420 loaded
# train_dataset2: image 421 loaded
# train_dataset2: image 422 loaded
# train_dataset2: image 423 loaded
# train_dataset2: image 424 loaded
# train_dataset2: image 425 loaded
# train_dataset2: image 426 loaded
# train_dataset2: image 427 loaded
# train_dataset2: image 428 loaded
# train_dataset2: image 429 loaded
# train_dataset2: image 430 loaded
# train_dataset2: image 431 loaded
# train_dataset2: image 432 loaded
# train_dataset2: image 433 loaded
# train_dataset2: image 434 loaded
# train_dataset2: image 435 loaded
# train_dataset2: image 436 loaded
# train_dataset2: image 437 loaded
# train_dataset2: image 438 loaded
# train_dataset2: image 439 loaded
# train_dataset2: image 440 loaded
# train_dataset2: image 441 loaded
# train_dataset2: image 442 loaded
# train_dataset2: image 443 loaded
# train_dataset2: image 444 loaded
# train_dataset2: image 445 loaded
# train_dataset2: image 446 loaded
# train_dataset2: image 447 loaded
# train_dataset2: image 448 loaded
# train_dataset2: image 449 loaded
# train_dataset2: image 450 loaded
# train_dataset2: image 451 loaded
# train_dataset2: image 452 loaded
# train_dataset2: image 453 loaded
# train_dataset2: image 454 loaded
# train_dataset2: image 455 loaded
# train_dataset2: image 456 loaded
# train_dataset2: image 457 loaded
# train_dataset2: image 458 loaded
# train_dataset2: image 459 loaded
# train_dataset2: image 460 loaded
# train_dataset2: image 461 loaded
# train_dataset2: image 462 loaded
# train_dataset2: image 463 loaded
# train_dataset2: image 464 loaded
# train_dataset2: image 465 loaded
# train_dataset2: image 466 loaded
# train_dataset2: image 467 loaded
# train_dataset2: image 468 loaded
# train_dataset2: image 469 loaded
# train_dataset2: image 470 loaded
# train_dataset2: image 471 loaded
# train_dataset2: image 472 loaded
# train_dataset2: image 473 loaded
# train_dataset2: image 474 loaded
# train_dataset2: image 475 loaded
# train_dataset2: image 476 loaded
# train_dataset2: image 477 loaded
# train_dataset2: image 478 loaded
# train_dataset2: image 479 loaded
# train_dataset2: image 480 loaded
# train_dataset2: image 481 loaded
# train_dataset2: image 482 loaded
# train_dataset2: image 483 loaded
# train_dataset2: image 484 loaded
# train_dataset2: image 485 loaded
# train_dataset2: image 486 loaded
# train_dataset2: image 487 loaded
# train_dataset2: image 488 loaded
# train_dataset2: image 489 loaded
# train_dataset2: image 490 loaded
# train_dataset2: image 491 loaded
# train_dataset2: image 492 loaded
# train_dataset2: image 493 loaded
# train_dataset2: image 494 loaded
# train_dataset2: image 495 loaded
# train_dataset2: image 496 loaded
# train_dataset2: image 497 loaded
# train_dataset2: image 498 loaded
# train_dataset2: image 499 loaded
# train_dataset2: image 500 loaded
# test_dataset2: image 1 loaded
# test_dataset2: image 2 loaded
# test_dataset2: image 3 loaded
# test_dataset2: image 4 loaded
# test_dataset2: image 5 loaded
# test_dataset2: image 6 loaded
# test_dataset2: image 7 loaded
# test_dataset2: image 8 loaded
# test_dataset2: image 9 loaded
# test_dataset2: image 10 loaded
# test_dataset2: image 11 loaded
# test_dataset2: image 12 loaded
# test_dataset2: image 13 loaded
# test_dataset2: image 14 loaded
# test_dataset2: image 15 loaded
# test_dataset2: image 16 loaded
# test_dataset2: image 17 loaded
# test_dataset2: image 18 loaded
# test_dataset2: image 19 loaded
# test_dataset2: image 20 loaded
# test_dataset2: image 21 loaded
# test_dataset2: image 22 loaded
# test_dataset2: image 23 loaded
# test_dataset2: image 24 loaded
# test_dataset2: image 25 loaded
# test_dataset2: image 26 loaded
# test_dataset2: image 27 loaded
# test_dataset2: image 28 loaded
# test_dataset2: image 29 loaded
# test_dataset2: image 30 loaded
# test_dataset2: image 31 loaded
# test_dataset2: image 32 loaded
# test_dataset2: image 33 loaded
# test_dataset2: image 34 loaded
# test_dataset2: image 35 loaded
# test_dataset2: image 36 loaded
# test_dataset2: image 37 loaded
# test_dataset2: image 38 loaded
# test_dataset2: image 39 loaded
# test_dataset2: image 40 loaded
# test_dataset2: image 41 loaded
# test_dataset2: image 42 loaded
# test_dataset2: image 43 loaded
# test_dataset2: image 44 loaded
# test_dataset2: image 45 loaded
# test_dataset2: image 46 loaded
# test_dataset2: image 47 loaded
# test_dataset2: image 48 loaded
# test_dataset2: image 49 loaded
# test_dataset2: image 50 loaded
# test_dataset2: image 51 loaded
# test_dataset2: image 52 loaded
# test_dataset2: image 53 loaded
# test_dataset2: image 54 loaded
# test_dataset2: image 55 loaded
# test_dataset2: image 56 loaded
# test_dataset2: image 57 loaded
# test_dataset2: image 58 loaded
# test_dataset2: image 59 loaded
# test_dataset2: image 60 loaded
# test_dataset2: image 61 loaded
# test_dataset2: image 62 loaded
# test_dataset2: image 63 loaded
# test_dataset2: image 64 loaded
# test_dataset2: image 65 loaded
# test_dataset2: image 66 loaded
# test_dataset2: image 67 loaded
# test_dataset2: image 68 loaded
# test_dataset2: image 69 loaded
# test_dataset2: image 70 loaded
# test_dataset2: image 71 loaded
# test_dataset2: image 72 loaded
# test_dataset2: image 73 loaded
# test_dataset2: image 74 loaded
# test_dataset2: image 75 loaded
# test_dataset2: image 76 loaded
# test_dataset2: image 77 loaded
# test_dataset2: image 78 loaded
# test_dataset2: image 79 loaded
# test_dataset2: image 80 loaded
# test_dataset2: image 81 loaded
# test_dataset2: image 82 loaded
# test_dataset2: image 83 loaded
# test_dataset2: image 84 loaded
# test_dataset2: image 85 loaded
# test_dataset2: image 86 loaded
# test_dataset2: image 87 loaded
# test_dataset2: image 88 loaded
# test_dataset2: image 89 loaded
# test_dataset2: image 90 loaded
# test_dataset2: image 91 loaded
# test_dataset2: image 92 loaded
# test_dataset2: image 93 loaded
# test_dataset2: image 94 loaded
# test_dataset2: image 95 loaded
# test_dataset2: image 96 loaded
# test_dataset2: image 97 loaded
# test_dataset2: image 98 loaded
# test_dataset2: image 99 loaded
# test_dataset2: image 100 loaded

# %%
print(train_image_tensor_array.shape)
print(test_image_tensor_array.shape)
# Out:
# (500, 480, 1280, 3)
# (100, 480, 1280, 3)

# %%
plt.imshow(train_image_tensor_array[0]/255)

# %%
BUFFER_SIZE = 500 # buffer size is the number of images to train.
BATCH_SIZE = 32
IMG_WIDTH = 256
IMG_HEIGHT = 256

# %%
# load, 作用是把图片左右两半分开，左边的图片是input image， 右边的图片是real image。
def load(image_array):
    seg = image_array.shape[1]
    seg //= 2
    input_image = image_array[:, :seg, :]
    real_image = image_array[:, seg:, :]

    input_image = tf.cast(input_image, tf.float32)
    real_image = tf.cast(real_image, tf.float32)

    return input_image, real_image

# %%
def resize(input_image, real_image, height, width):
  input_image = tf.image.resize(input_image, [height, width],
                                method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
  real_image = tf.image.resize(real_image, [height, width],
                               method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)

  return input_image, real_image

# %%
def random_crop(input_image, real_image):
  stacked_image = tf.stack([input_image, real_image], axis=0)
  cropped_image = tf.image.random_crop(
      stacked_image, size=[2, IMG_HEIGHT, IMG_WIDTH, 3])

  return cropped_image[0], cropped_image[1]

# %%
# 归一化, normalize, 使像素的值都在（-1，1）之间。
def normalize(input_image, real_image):
  input_image = (input_image / 127.5) - 1
  real_image = (real_image / 127.5) - 1

  return input_image, real_image

# %%
@tf.function()
def random_jitter(input_image, real_image):
  # Resizing to 286x286
  input_image, real_image = resize(input_image, real_image, 286, 286)

  # Random cropping back to 256x256
  input_image, real_image = random_crop(input_image, real_image)

  if tf.random.uniform(()) > 0.5:
    # Random mirroring
    input_image = tf.image.flip_left_right(input_image)
    real_image = tf.image.flip_left_right(real_image)

  return input_image, real_image

# %%
def load_image_train(image_array):
  input_image, real_image = load(image_array)
  input_image, real_image = random_jitter(input_image, real_image)
  input_image, real_image = normalize(input_image, real_image)

  return input_image, real_image

# %%
def load_image_test(image_array):
  input_image, real_image = load(image_array)
  input_image, real_image = resize(input_image, real_image,
                                   IMG_HEIGHT, IMG_WIDTH)
  input_image, real_image = normalize(input_image, real_image)

  return input_image, real_image

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(train_image_tensor_array)

train_dataset = train_dataset.map(load_image_train,
                                  num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.shuffle(BUFFER_SIZE)
train_dataset = train_dataset.batch(BATCH_SIZE)

# %%
train_dataset
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None))>

# %%
test_dataset = tf.data.Dataset.from_tensor_slices(test_image_tensor_array)
test_dataset = test_dataset.map(load_image_test)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
test_dataset
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None))>

# %%
# build_generator

# %%
OUTPUT_CHANNELS = 3

# %%
def downsample(filters, size, apply_batchnorm=True):
  initializer = tf.random_normal_initializer(0., 0.02)

  result = tf.keras.Sequential()
  result.add(
      tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                             kernel_initializer=initializer, use_bias=False))

  if apply_batchnorm:
    result.add(tf.keras.layers.BatchNormalization())

  result.add(tf.keras.layers.LeakyReLU())

  return result

# %%
def upsample(filters, size, apply_dropout=False):
  initializer = tf.random_normal_initializer(0., 0.02)

  result = tf.keras.Sequential()
  result.add(
    tf.keras.layers.Conv2DTranspose(filters, size, strides=2,
                                    padding='same',
                                    kernel_initializer=initializer,
                                    use_bias=False))

  result.add(tf.keras.layers.BatchNormalization())

  if apply_dropout:
      result.add(tf.keras.layers.Dropout(0.5))

  result.add(tf.keras.layers.ReLU())

  return result

# %%
def Generator():
  inputs = tf.keras.layers.Input(shape=[256, 256, 3])

  down_stack = [
    downsample(64, 4, apply_batchnorm=False),  # (batch_size, 128, 128, 64)
    downsample(128, 4),  # (batch_size, 64, 64, 128)
    downsample(256, 4),  # (batch_size, 32, 32, 256)
    downsample(512, 4),  # (batch_size, 16, 16, 512)
    downsample(512, 4),  # (batch_size, 8, 8, 512)
    downsample(512, 4),  # (batch_size, 4, 4, 512)
    downsample(512, 4),  # (batch_size, 2, 2, 512)
    downsample(512, 4),  # (batch_size, 1, 1, 512)
  ]

  up_stack = [
    upsample(512, 4, apply_dropout=True),  # (batch_size, 2, 2, 1024)
    upsample(512, 4, apply_dropout=True),  # (batch_size, 4, 4, 1024)
    upsample(512, 4, apply_dropout=True),  # (batch_size, 8, 8, 1024)
    upsample(512, 4),  # (batch_size, 16, 16, 1024)
    upsample(256, 4),  # (batch_size, 32, 32, 512)
    upsample(128, 4),  # (batch_size, 64, 64, 256)
    upsample(64, 4),  # (batch_size, 128, 128, 128)
  ]

  initializer = tf.random_normal_initializer(0., 0.02)
  last = tf.keras.layers.Conv2DTranspose(OUTPUT_CHANNELS, 4,
                                         strides=2,
                                         padding='same',
                                         kernel_initializer=initializer,
                                         activation='tanh')  # (batch_size, 256, 256, 3)

  x = inputs

  # Downsampling through the model
  skips = []
  for down in down_stack:
    x = down(x)
    skips.append(x)

  skips = reversed(skips[:-1])

  # Upsampling and establishing the skip connections
  for up, skip in zip(up_stack, skips):
    x = up(x)
    x = tf.keras.layers.Concatenate()([x, skip])

  x = last(x)

  return tf.keras.Model(inputs=inputs, outputs=x)

# %%
generator = Generator()
tf.keras.utils.plot_model(generator, show_shapes=True, dpi=64)

# %%
# define generator loss

# %%
LAMBDA = 100

# %%
loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
def generator_loss(disc_generated_output, gen_output, target):
  gan_loss = loss_object(tf.ones_like(disc_generated_output), disc_generated_output)

  # Mean absolute error
  l1_loss = tf.reduce_mean(tf.abs(target - gen_output))

  total_gen_loss = gan_loss + (LAMBDA * l1_loss)

  return total_gen_loss, gan_loss, l1_loss

# %%
# build the discriminator

# %%
def Discriminator():
  initializer = tf.random_normal_initializer(0., 0.02)

  inp = tf.keras.layers.Input(shape=[256, 256, 3], name='input_image')
  tar = tf.keras.layers.Input(shape=[256, 256, 3], name='target_image')

  x = tf.keras.layers.concatenate([inp, tar])  # (batch_size, 256, 256, channels*2)

  down1 = downsample(64, 4, False)(x)  # (batch_size, 128, 128, 64)
  down2 = downsample(128, 4)(down1)  # (batch_size, 64, 64, 128)
  down3 = downsample(256, 4)(down2)  # (batch_size, 32, 32, 256)

  zero_pad1 = tf.keras.layers.ZeroPadding2D()(down3)  # (batch_size, 34, 34, 256)
  conv = tf.keras.layers.Conv2D(512, 4, strides=1,
                                kernel_initializer=initializer,
                                use_bias=False)(zero_pad1)  # (batch_size, 31, 31, 512)

  batchnorm1 = tf.keras.layers.BatchNormalization()(conv)

  leaky_relu = tf.keras.layers.LeakyReLU()(batchnorm1)

  zero_pad2 = tf.keras.layers.ZeroPadding2D()(leaky_relu)  # (batch_size, 33, 33, 512)

  last = tf.keras.layers.Conv2D(1, 4, strides=1,
                                kernel_initializer=initializer)(zero_pad2)  # (batch_size, 30, 30, 1)

  return tf.keras.Model(inputs=[inp, tar], outputs=last)

# %%
discriminator = Discriminator()
tf.keras.utils.plot_model(discriminator, show_shapes=True, dpi=64)

# %%
# define discriminator loss

# %%
def discriminator_loss(disc_real_output, disc_generated_output):
  real_loss = loss_object(tf.ones_like(disc_real_output), disc_real_output)

  generated_loss = loss_object(tf.zeros_like(disc_generated_output), disc_generated_output)

  total_disc_loss = real_loss + generated_loss

  return total_disc_loss

# %%
# optimizers

# %%
generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %%
# generate images

# %%
def generate_images(model, test_input, tar):
  prediction = model(test_input, training=True)
  plt.figure(figsize=(15, 15))

  display_list = [test_input[0], tar[0], prediction[0]]
  title = ['Input Image', 'Target Image', 'Generated Image']

  for i in range(3):
    plt.subplot(1, 3, i+1)
    plt.title(title[i])
    # Getting the pixel values in the [0, 1] range to plot.
    plt.imshow(display_list[i] * 0.5 + 0.5)
    plt.axis('off')
  plt.show()

# %%
# training

# %%
@tf.function
def train_step(input_image, target, step):
  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    gen_output = generator(input_image, training=True)

    disc_real_output = discriminator([input_image, target], training=True)
    disc_generated_output = discriminator([input_image, gen_output], training=True)

    gen_total_loss, gen_gan_loss, gen_l1_loss = generator_loss(disc_generated_output, gen_output, target)
    disc_loss = discriminator_loss(disc_real_output, disc_generated_output)

  generator_gradients = gen_tape.gradient(gen_total_loss,
                                          generator.trainable_variables)
  discriminator_gradients = disc_tape.gradient(disc_loss,
                                               discriminator.trainable_variables)

  generator_optimizer.apply_gradients(zip(generator_gradients,
                                          generator.trainable_variables))
  discriminator_optimizer.apply_gradients(zip(discriminator_gradients,
                                              discriminator.trainable_variables))

# %%
def fit(train_ds, test_ds, steps):
  for step, (input_image, target) in train_ds.repeat().take(steps).enumerate():

    train_step(input_image, target, step)

    # show the generated images for every 5 epochs
    if (step+1) % 5 == 0:
      print(f'epoch {step+1} finished')
      for inp, tar in test_dataset.take(1):
        generate_images(generator, inp, tar)

# %%
fit(train_dataset, test_dataset, steps=3000)

# %%
for inp, tar in test_dataset.take(20):
  generate_images(generator, inp, tar)

# %%
# generator model summary
generator.summary()

# %%
# save the models
generator.save('/content/drive/MyDrive/CGAN_PIX2PIX/models/model_3.h5')
